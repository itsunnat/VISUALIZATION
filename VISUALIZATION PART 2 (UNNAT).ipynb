# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
titanic=sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
sns.displot(titanic["age"])
plt.show()

# %%
#Chart showing age wise distribution and class wise division in each group

sns.displot(titanic,x="age",hue="class")
plt.show()

# %%
#Chart showing age wise distribution and Sex wise division in each group

sns.displot(titanic,x="age",hue="sex",palette="rocket")
plt.show()

# %%
#Chart showing age wise distribution and Survived wise division in each group

sns.displot(titanic,x="age",hue="survived",palette="Reds")
plt.show()

# %%
#Chart showing age wise distribution and embarked wise division in each group

sns.displot(titanic,x="age",hue="embarked")
plt.show()

# %%
pip install seaborn --upgrade
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
sns.pairplot(titanic)
plt.show()

# %%
sns.catplot(data=titanic,y="survived",x="sex",hue="class",kind="violin")
plt.show()

# %%
sns.catplot(data=titanic,y="survived",x="sex",hue="class",kind="bar")
plt.show()

# %%
#Create count of survived and not survived peoples

# %%
sns.countplot(data=titanic,x="survived")
plt.show()

# %%
#Create count of people class wise
sns.countplot(data=titanic,y="pclass")
plt.show()

# %%
#create sex wise count of peoples
sns.countplot(data=titanic,y="sex")
plt.show()

# %%
#create pichart to check howmany percente were male and female

# %%
color=sns.color_palette("flare")
titanic["sex"].value_counts().plot(kind="pie",colors=color,autopct="%.0f%%")
# Out:
# <AxesSubplot:ylabel='sex'>

# %%
sns.boxplot(titanic,x="embark_town")
plt.show()

# %%
titanic["embark_town"].value_counts()
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64
